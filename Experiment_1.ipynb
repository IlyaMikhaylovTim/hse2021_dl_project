# %% [markdown]
# ### Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
PATH_TO_FOLDER = '/content/drive/MyDrive/DL_project/EXPERIMENTS'

# %%
# %cd {PATH_TO_FOLDER}
# Out:
# /content/drive/MyDrive/DL_project/EXPERIMENTS

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from models import NAC, Complex_NAC, MLP

# %%
import math
import random
import numpy as np
from tqdm.notebook import tqdm
from copy import deepcopy

import torch
import torch.nn as nn
import torch.nn.functional as F

# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)

# Device configuration
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# %%capture
# !pip install wandb --upgrade

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ### Parameters

# %%
NAMES = dict(
    project = 'Experiment_1',
    tags = 'try_1'
)

MODEL_PARAMETERS = dict(
    in_dim=2,
    out_dim=1,
    NUM_LAYERS = 1,
    HIDDEN_DIM = 2,
)

ARITHMETIC_PARAMETERS = dict(
    num_train=500, 
    num_test=50,
    dim=100, 
    num_sum=5,
    RANGE = [5, 10]
)

TRAIN_PARAMETERS = dict(
                        LEARNING_RATE = 1e-2,
                        # NUM_ITERS = int(1e5),
                        NUM_ITERS = int(50000),
                        activation='relu6'
                        )

ARITHMETIC_FUNCTIONS = {
    'add': lambda x, y: x + y,
    'sub': lambda x, y: x - y,
    'mul': lambda x, y: x * y,
    'div': lambda x, y: x / y,
    # 'squared': lambda x, y: torch.pow(x, 2),
    # 'root': lambda x, y: torch.sqrt(x)
    }

MODELS = {
        'NAC': NAC, 
        'Complex_NAC': NAC
        }

# %%
# def get_id():
#     id_dct = {}
#     for i, key in enumerate(ARITHMETIC_FUNCTIONS.keys()):
#         id_dct[key] = i
#     return id_dct

# FUNC_id = get_id()

# %% [markdown]
# ### Config for Wandb

# %%
def create_config(model, function):
    config = {'model': model,
              'function': function}
              
    models = MODEL_PARAMETERS.copy()
    funcs = ARITHMETIC_PARAMETERS.copy()
    params = TRAIN_PARAMETERS.copy()
    names = NAMES.copy()

    for key, value in models.items():
        config[key] = value
    for key, value in funcs.items():
        config[key] = value
    for key, value in params.items():
        config[key] = value
    for key, value in names.items():
        config[key] = value

    return config

# %% [markdown]
# ### Example of config

# %%
config = create_config('NAC', 'add')

# %%
config
# Out:
# {'HIDDEN_DIM': 2,
#  'LEARNING_RATE': 0.01,
#  'NUM_ITERS': 50000,
#  'NUM_LAYERS': 1,
#  'RANGE': [5, 10],
#  'activation': 'relu6',
#  'dim': 100,
#  'function': 'add',
#  'in_dim': 2,
#  'model': 'NAC',
#  'num_sum': 5,
#  'num_test': 50,
#  'num_train': 500,
#  'out_dim': 1,
#  'project': 'Experiment_1',
#  'tags': 'try_1'}

# %% [markdown]
# ### Iteration on models and arithmetic functions

# %%
mdls = MODELS.keys()
fncts = ARITHMETIC_FUNCTIONS.keys()

for function in fncts:
    for arch in mdls:
        config = create_config(arch, function)
        # Build, train and analyze the model with the pipeline
        model = model_pipeline(config)
# Out:
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">add_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/k7qynaf9" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/k7qynaf9</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191650-k7qynaf9</code><br/><br/>
# 	1/50000: loss: 3937.5056152 - mea: 62.5801811
# 	1001/50000: loss: 1.1238458 - mea: 1.0577044
# 	2001/50000: loss: 0.0087257 - mea: 0.0932048
# 	3001/50000: loss: 0.0000705 - mea: 0.0083774
# 	4001/50000: loss: 0.0000006 - mea: 0.0007539
# 	5001/50000: loss: 0.0000000 - mea: 0.0000803
# 	6001/50000: loss: 0.0000000 - mea: 0.0000247
# 	7001/50000: loss: 0.0000000 - mea: 0.0000197
# 	8001/50000: loss: 0.0000000 - mea: 0.0000113
# 	9001/50000: loss: 0.0000000 - mea: 0.0000113
# 	10001/50000: loss: 0.0000000 - mea: 0.0000113
# 	11001/50000: loss: 0.0000000 - mea: 0.0000074
# 	12001/50000: loss: 0.0000000 - mea: 0.0000074
# 	13001/50000: loss: 0.0000000 - mea: 0.0000074
# 	14001/50000: loss: 0.0000000 - mea: 0.0000074
# 	15001/50000: loss: 0.0000000 - mea: 0.0000074
# 	16001/50000: loss: 0.0000000 - mea: 0.0000074
# 	17001/50000: loss: 0.0000000 - mea: 0.0000074
# 	18001/50000: loss: 0.0000000 - mea: 0.0000074
# 	19001/50000: loss: 0.0000000 - mea: 0.0000074
# 	20001/50000: loss: 0.0000000 - mea: 0.0000074
# 	21001/50000: loss: 0.0000000 - mea: 0.0000074
# 	22001/50000: loss: 0.0000000 - mea: 0.0000074
# 	23001/50000: loss: 0.0000000 - mea: 0.0000000
# 	24001/50000: loss: 0.0000000 - mea: 0.0000000
# 	25001/50000: loss: 0.0000000 - mea: 0.0000000
# 	26001/50000: loss: 0.0000000 - mea: 0.0000000
# 	27001/50000: loss: 0.0000000 - mea: 0.0000000
# 	28001/50000: loss: 0.0000000 - mea: 0.0000000
# 	29001/50000: loss: 0.0000000 - mea: 0.0000000
# 	30001/50000: loss: 0.0000000 - mea: 0.0000000
# 	31001/50000: loss: 0.0000000 - mea: 0.0000000
# 	32001/50000: loss: 0.0000000 - mea: 0.0000000
# 	33001/50000: loss: 0.0000000 - mea: 0.0000000
# 	34001/50000: loss: 0.0000000 - mea: 0.0000000
# 	35001/50000: loss: 0.0000000 - mea: 0.0000000
# 	36001/50000: loss: 0.0000000 - mea: 0.0000000
# 	37001/50000: loss: 0.0000000 - mea: 0.0000000
# 	38001/50000: loss: 0.0000000 - mea: 0.0000000
# 	39001/50000: loss: 0.0000000 - mea: 0.0000000
# 	40001/50000: loss: 0.0000000 - mea: 0.0000000
# 	41001/50000: loss: 0.0000000 - mea: 0.0000000
# 	42001/50000: loss: 0.0000000 - mea: 0.0000000
# 	43001/50000: loss: 0.0000000 - mea: 0.0000000
# 	44001/50000: loss: 0.0000000 - mea: 0.0000000
# 	45001/50000: loss: 0.0000000 - mea: 0.0000000
# 	46001/50000: loss: 0.0000000 - mea: 0.0000000
# 	47001/50000: loss: 0.0000000 - mea: 0.0000000
# 	48001/50000: loss: 0.0000000 - mea: 0.0000000
# 	49001/50000: loss: 0.0000000 - mea: 0.0000000
# model_type: NAC
# function: add
# test_result: 0.0
# normalized_test_result: 0.0
# <br/>Waiting for W&B process to finish, PID 673<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191650-k7qynaf9/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191650-k7qynaf9/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.0</td></tr><tr><td>mean_absolute_error</td><td>0.0</td></tr><tr><td>_runtime</td><td>23</td></tr><tr><td>_timestamp</td><td>1623439033</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">add_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/k7qynaf9" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/k7qynaf9</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">add_Complex_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/3s7arjj4" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/3s7arjj4</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191719-3s7arjj4</code><br/><br/>
# 	1/50000: loss: 5159.7626953 - mea: 71.6897354
# 	1001/50000: loss: 1.6701837 - mea: 1.2899815
# 	2001/50000: loss: 0.0130567 - mea: 0.1140550
# 	3001/50000: loss: 0.0001070 - mea: 0.0103245
# 	4001/50000: loss: 0.0000009 - mea: 0.0009364
# 	5001/50000: loss: 0.0000000 - mea: 0.0000923
# 	6001/50000: loss: 0.0000000 - mea: 0.0000267
# 	7001/50000: loss: 0.0000000 - mea: 0.0000188
# 	8001/50000: loss: 0.0000000 - mea: 0.0000112
# 	9001/50000: loss: 0.0000000 - mea: 0.0000112
# 	10001/50000: loss: 0.0000000 - mea: 0.0000112
# 	11001/50000: loss: 0.0000000 - mea: 0.0000074
# 	12001/50000: loss: 0.0000000 - mea: 0.0000074
# 	13001/50000: loss: 0.0000000 - mea: 0.0000074
# 	14001/50000: loss: 0.0000000 - mea: 0.0000074
# 	15001/50000: loss: 0.0000000 - mea: 0.0000074
# 	16001/50000: loss: 0.0000000 - mea: 0.0000074
# 	17001/50000: loss: 0.0000000 - mea: 0.0000074
# 	18001/50000: loss: 0.0000000 - mea: 0.0000074
# 	19001/50000: loss: 0.0000000 - mea: 0.0000074
# 	20001/50000: loss: 0.0000000 - mea: 0.0000074
# 	21001/50000: loss: 0.0000000 - mea: 0.0000074
# 	22001/50000: loss: 0.0000000 - mea: 0.0000038
# 	23001/50000: loss: 0.0000000 - mea: 0.0000038
# 	24001/50000: loss: 0.0000000 - mea: 0.0000038
# 	25001/50000: loss: 0.0000000 - mea: 0.0000038
# 	26001/50000: loss: 0.0000000 - mea: 0.0000038
# 	27001/50000: loss: 0.0000000 - mea: 0.0000000
# 	28001/50000: loss: 0.0000000 - mea: 0.0000000
# 	29001/50000: loss: 0.0000000 - mea: 0.0000000
# 	30001/50000: loss: 0.0000000 - mea: 0.0000000
# 	31001/50000: loss: 0.0000000 - mea: 0.0000000
# 	32001/50000: loss: 0.0000000 - mea: 0.0000000
# 	33001/50000: loss: 0.0000000 - mea: 0.0000000
# 	34001/50000: loss: 0.0000000 - mea: 0.0000000
# 	35001/50000: loss: 0.0000000 - mea: 0.0000000
# 	36001/50000: loss: 0.0000000 - mea: 0.0000000
# 	37001/50000: loss: 0.0000000 - mea: 0.0000000
# 	38001/50000: loss: 0.0000000 - mea: 0.0000000
# 	39001/50000: loss: 0.0000000 - mea: 0.0000000
# 	40001/50000: loss: 0.0000000 - mea: 0.0000000
# 	41001/50000: loss: 0.0000000 - mea: 0.0000000
# 	42001/50000: loss: 0.0000000 - mea: 0.0000000
# 	43001/50000: loss: 0.0000000 - mea: 0.0000000
# 	44001/50000: loss: 0.0000000 - mea: 0.0000000
# 	45001/50000: loss: 0.0000000 - mea: 0.0000000
# 	46001/50000: loss: 0.0000000 - mea: 0.0000000
# 	47001/50000: loss: 0.0000000 - mea: 0.0000000
# 	48001/50000: loss: 0.0000000 - mea: 0.0000000
# 	49001/50000: loss: 0.0000000 - mea: 0.0000000
# model_type: Complex_NAC
# function: add
# test_result: 0.0
# normalized_test_result: 0.0
# <br/>Waiting for W&B process to finish, PID 719<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191719-3s7arjj4/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191719-3s7arjj4/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.0</td></tr><tr><td>mean_absolute_error</td><td>0.0</td></tr><tr><td>_runtime</td><td>24</td></tr><tr><td>_timestamp</td><td>1623439063</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">add_Complex_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/3s7arjj4" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/3s7arjj4</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">sub_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/2a897561" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/2a897561</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191751-2a897561</code><br/><br/>
# 	1/50000: loss: 337.8469849 - mea: 17.7205048
# 	1001/50000: loss: 0.1812958 - mea: 0.3366335
# 	2001/50000: loss: 0.0011750 - mea: 0.0271012
# 	3001/50000: loss: 0.0000095 - mea: 0.0024385
# 	4001/50000: loss: 0.0000001 - mea: 0.0002239
# 	5001/50000: loss: 0.0000000 - mea: 0.0000336
# 	6001/50000: loss: 0.0000000 - mea: 0.0000178
# 	7001/50000: loss: 0.0000000 - mea: 0.0000133
# 	8001/50000: loss: 0.0000000 - mea: 0.0000114
# 	9001/50000: loss: 0.0000000 - mea: 0.0000097
# 	10001/50000: loss: 0.0000000 - mea: 0.0000087
# 	11001/50000: loss: 0.0000000 - mea: 0.0000085
# 	12001/50000: loss: 0.0000000 - mea: 0.0000075
# 	13001/50000: loss: 0.0000000 - mea: 0.0000075
# 	14001/50000: loss: 0.0000000 - mea: 0.0000070
# 	15001/50000: loss: 0.0000000 - mea: 0.0000065
# 	16001/50000: loss: 0.0000000 - mea: 0.0000061
# 	17001/50000: loss: 0.0000000 - mea: 0.0000062
# 	18001/50000: loss: 0.0000000 - mea: 0.0000053
# 	19001/50000: loss: 0.0000000 - mea: 0.0000056
# 	20001/50000: loss: 0.0000000 - mea: 0.0000050
# 	21001/50000: loss: 0.0000000 - mea: 0.0000050
# 	22001/50000: loss: 0.0000000 - mea: 0.0000050
# 	23001/50000: loss: 0.0000000 - mea: 0.0000050
# 	24001/50000: loss: 0.0000000 - mea: 0.0000043
# 	25001/50000: loss: 0.0000000 - mea: 0.0000043
# 	26001/50000: loss: 0.0000000 - mea: 0.0000043
# 	27001/50000: loss: 0.0000000 - mea: 0.0000045
# 	28001/50000: loss: 0.0000000 - mea: 0.0000045
# 	29001/50000: loss: 0.0000000 - mea: 0.0000041
# 	30001/50000: loss: 0.0000000 - mea: 0.0000041
# 	31001/50000: loss: 0.0000000 - mea: 0.0000047
# 	32001/50000: loss: 0.0000000 - mea: 0.0000035
# 	33001/50000: loss: 0.0000000 - mea: 0.0000035
# 	34001/50000: loss: 0.0000000 - mea: 0.0000041
# 	35001/50000: loss: 0.0000000 - mea: 0.0000035
# 	36001/50000: loss: 0.0000000 - mea: 0.0000032
# 	37001/50000: loss: 0.0000000 - mea: 0.0000032
# 	38001/50000: loss: 0.0000000 - mea: 0.0000032
# 	39001/50000: loss: 0.0000000 - mea: 0.0000032
# 	40001/50000: loss: 0.0000000 - mea: 0.0000032
# 	41001/50000: loss: 0.0000000 - mea: 0.0000032
# 	42001/50000: loss: 0.0000000 - mea: 0.0000032
# 	43001/50000: loss: 0.0000000 - mea: 0.0000032
# 	44001/50000: loss: 0.0000000 - mea: 0.0000032
# 	45001/50000: loss: 0.0000000 - mea: 0.0000032
# 	46001/50000: loss: 0.0000000 - mea: 0.0000032
# 	47001/50000: loss: 0.0000000 - mea: 0.0000032
# 	48001/50000: loss: 0.0000000 - mea: 0.0000028
# 	49001/50000: loss: 0.0000000 - mea: 0.0000028
# model_type: NAC
# function: sub
# test_result: 3.051757857974735e-06
# normalized_test_result: 2.6397439577777215e-05
# <br/>Waiting for W&B process to finish, PID 761<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191751-2a897561/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191751-2a897561/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.0</td></tr><tr><td>mean_absolute_error</td><td>0.0</td></tr><tr><td>_runtime</td><td>23</td></tr><tr><td>_timestamp</td><td>1623439094</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sub_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/2a897561" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/2a897561</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">sub_Complex_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/subyrdjm" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/subyrdjm</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191822-subyrdjm</code><br/><br/>
# 	1/50000: loss: 280.9273071 - mea: 15.9568434
# 	1001/50000: loss: 0.1685604 - mea: 0.3309749
# 	2001/50000: loss: 0.0010934 - mea: 0.0266575
# 	3001/50000: loss: 0.0000089 - mea: 0.0024015
# 	4001/50000: loss: 0.0000001 - mea: 0.0002209
# 	5001/50000: loss: 0.0000000 - mea: 0.0000338
# 	6001/50000: loss: 0.0000000 - mea: 0.0000182
# 	7001/50000: loss: 0.0000000 - mea: 0.0000135
# 	8001/50000: loss: 0.0000000 - mea: 0.0000114
# 	9001/50000: loss: 0.0000000 - mea: 0.0000099
# 	10001/50000: loss: 0.0000000 - mea: 0.0000087
# 	11001/50000: loss: 0.0000000 - mea: 0.0000083
# 	12001/50000: loss: 0.0000000 - mea: 0.0000074
# 	13001/50000: loss: 0.0000000 - mea: 0.0000074
# 	14001/50000: loss: 0.0000000 - mea: 0.0000065
# 	15001/50000: loss: 0.0000000 - mea: 0.0000065
# 	16001/50000: loss: 0.0000000 - mea: 0.0000062
# 	17001/50000: loss: 0.0000000 - mea: 0.0000060
# 	18001/50000: loss: 0.0000000 - mea: 0.0000053
# 	19001/50000: loss: 0.0000000 - mea: 0.0000053
# 	20001/50000: loss: 0.0000000 - mea: 0.0000053
# 	21001/50000: loss: 0.0000000 - mea: 0.0000053
# 	22001/50000: loss: 0.0000000 - mea: 0.0000047
# 	23001/50000: loss: 0.0000000 - mea: 0.0000047
# 	24001/50000: loss: 0.0000000 - mea: 0.0000042
# 	25001/50000: loss: 0.0000000 - mea: 0.0000042
# 	26001/50000: loss: 0.0000000 - mea: 0.0000042
# 	27001/50000: loss: 0.0000000 - mea: 0.0000042
# 	28001/50000: loss: 0.0000000 - mea: 0.0000042
# 	29001/50000: loss: 0.0000000 - mea: 0.0000042
# 	30001/50000: loss: 0.0000000 - mea: 0.0000039
# 	31001/50000: loss: 0.0000000 - mea: 0.0000042
# 	32001/50000: loss: 0.0000000 - mea: 0.0000039
# 	33001/50000: loss: 0.0000000 - mea: 0.0000036
# 	34001/50000: loss: 0.0000000 - mea: 0.0000036
# 	35001/50000: loss: 0.0000000 - mea: 0.0000036
# 	36001/50000: loss: 0.0000000 - mea: 0.0000036
# 	37001/50000: loss: 0.0000000 - mea: 0.0000036
# 	38001/50000: loss: 0.0000000 - mea: 0.0000032
# 	39001/50000: loss: 0.0000000 - mea: 0.0000032
# 	40001/50000: loss: 0.0000000 - mea: 0.0000032
# 	41001/50000: loss: 0.0000000 - mea: 0.0000032
# 	42001/50000: loss: 0.0000000 - mea: 0.0000032
# 	43001/50000: loss: 0.0000000 - mea: 0.0000032
# 	44001/50000: loss: 0.0000000 - mea: 0.0000032
# 	45001/50000: loss: 0.0000000 - mea: 0.0000032
# 	46001/50000: loss: 0.0000000 - mea: 0.0000032
# 	47001/50000: loss: 0.0000000 - mea: 0.0000032
# 	48001/50000: loss: 0.0000000 - mea: 0.0000049
# 	49001/50000: loss: 0.0000000 - mea: 0.0000032
# model_type: Complex_NAC
# function: sub
# test_result: 2.7465821403893642e-06
# normalized_test_result: 7.683715125315034e-05
# <br/>Waiting for W&B process to finish, PID 803<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191822-subyrdjm/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191822-subyrdjm/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.0</td></tr><tr><td>mean_absolute_error</td><td>0.0</td></tr><tr><td>_runtime</td><td>23</td></tr><tr><td>_timestamp</td><td>1623439125</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sub_Complex_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/subyrdjm" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/subyrdjm</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">mul_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/1nbwv6wh" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/1nbwv6wh</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191852-1nbwv6wh</code><br/><br/>
# 	1/50000: loss: 2011982.1250000 - mea: 1408.8945312
# 	1001/50000: loss: 1808265.6250000 - mea: 1335.1582031
# 	2001/50000: loss: 1807244.3750000 - mea: 1334.7780762
# 	3001/50000: loss: 1807228.8750000 - mea: 1334.7724609
# 	4001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	5001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	6001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	7001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	8001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	9001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	10001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	11001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	12001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	13001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	14001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	15001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	16001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	17001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	18001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	19001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	20001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	21001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	22001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	23001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	24001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	25001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	26001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	27001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	28001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	29001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	30001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	31001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	32001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	33001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	34001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	35001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	36001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	37001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	38001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	39001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	40001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	41001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	42001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	43001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	44001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	45001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	46001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	47001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	48001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# 	49001/50000: loss: 1807228.7500000 - mea: 1334.7724609
# model_type: NAC
# function: mul
# test_result: 1343.6168212890625
# normalized_test_result: 94.59621426378665
# <br/>Waiting for W&B process to finish, PID 843<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191852-1nbwv6wh/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191852-1nbwv6wh/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>1807228.75</td></tr><tr><td>mean_absolute_error</td><td>1334.77246</td></tr><tr><td>_runtime</td><td>24</td></tr><tr><td>_timestamp</td><td>1623439156</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">mul_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/1nbwv6wh" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/1nbwv6wh</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">mul_Complex_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/1z96180x" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/1z96180x</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191922-1z96180x</code><br/><br/>
# 	1/50000: loss: 1891392.5000000 - mea: 1364.7497559
# 	1001/50000: loss: 1736666.6250000 - mea: 1307.2900391
# 	2001/50000: loss: 1736439.1250000 - mea: 1307.2034912
# 	3001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	4001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	5001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	6001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	7001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	8001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	9001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	10001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	11001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	12001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	13001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	14001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	15001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	16001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	17001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	18001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	19001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	20001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	21001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	22001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	23001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	24001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	25001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	26001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	27001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	28001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	29001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	30001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	31001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	32001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	33001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	34001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	35001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	36001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	37001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	38001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	39001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	40001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	41001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	42001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	43001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	44001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	45001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	46001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	47001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	48001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# 	49001/50000: loss: 1736436.1250000 - mea: 1307.2025146
# model_type: Complex_NAC
# function: mul
# test_result: 1324.662353515625
# normalized_test_result: 94.08526864755841
# <br/>Waiting for W&B process to finish, PID 885<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191922-1z96180x/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191922-1z96180x/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>1736436.125</td></tr><tr><td>mean_absolute_error</td><td>1307.20251</td></tr><tr><td>_runtime</td><td>23</td></tr><tr><td>_timestamp</td><td>1623439186</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">mul_Complex_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/1z96180x" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/1z96180x</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">div_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/t9gyv4yf" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/t9gyv4yf</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191953-t9gyv4yf</code><br/><br/>
# 	1/50000: loss: 242.0960388 - mea: 15.5305729
# 	1001/50000: loss: 0.0152736 - mea: 0.1029180
# 	2001/50000: loss: 0.0191439 - mea: 0.1218680
# 	3001/50000: loss: 0.0130938 - mea: 0.0978282
# 	4001/50000: loss: 0.0097501 - mea: 0.0828895
# 	5001/50000: loss: 0.0078614 - mea: 0.0735343
# 	6001/50000: loss: 0.0067358 - mea: 0.0675039
# 	7001/50000: loss: 0.0060212 - mea: 0.0633824
# 	8001/50000: loss: 0.0055417 - mea: 0.0605038
# 	9001/50000: loss: 0.0052042 - mea: 0.0584386
# 	10001/50000: loss: 0.0049569 - mea: 0.0568928
# 	11001/50000: loss: 0.0047694 - mea: 0.0557211
# 	12001/50000: loss: 0.0046241 - mea: 0.0547918
# 	13001/50000: loss: 0.0045084 - mea: 0.0540403
# 	14001/50000: loss: 0.0044146 - mea: 0.0534681
# 	15001/50000: loss: 0.0043375 - mea: 0.0529991
# 	16001/50000: loss: 0.0042733 - mea: 0.0526041
# 	17001/50000: loss: 0.0042191 - mea: 0.0522654
# 	18001/50000: loss: 0.0041734 - mea: 0.0519855
# 	19001/50000: loss: 0.0041340 - mea: 0.0517402
# 	20001/50000: loss: 0.0041004 - mea: 0.0515284
# 	21001/50000: loss: 0.0040715 - mea: 0.0513398
# 	22001/50000: loss: 0.0040464 - mea: 0.0511791
# 	23001/50000: loss: 0.0040249 - mea: 0.0510408
# 	24001/50000: loss: 0.0040061 - mea: 0.0509193
# 	25001/50000: loss: 0.0039899 - mea: 0.0508154
# 	26001/50000: loss: 0.0039758 - mea: 0.0507247
# 	27001/50000: loss: 0.0039637 - mea: 0.0506456
# 	28001/50000: loss: 0.0039532 - mea: 0.0505750
# 	29001/50000: loss: 0.0039442 - mea: 0.0505132
# 	30001/50000: loss: 0.0039365 - mea: 0.0504614
# 	31001/50000: loss: 0.0039298 - mea: 0.0504178
# 	32001/50000: loss: 0.0039242 - mea: 0.0503805
# 	33001/50000: loss: 0.0039195 - mea: 0.0503491
# 	34001/50000: loss: 0.0039154 - mea: 0.0503218
# 	35001/50000: loss: 0.0039119 - mea: 0.0502990
# 	36001/50000: loss: 0.0039090 - mea: 0.0502789
# 	37001/50000: loss: 0.0039066 - mea: 0.0502627
# 	38001/50000: loss: 0.0039045 - mea: 0.0502486
# 	39001/50000: loss: 0.0039028 - mea: 0.0502374
# 	40001/50000: loss: 0.0039014 - mea: 0.0502278
# 	41001/50000: loss: 0.0039002 - mea: 0.0502200
# 	42001/50000: loss: 0.0038991 - mea: 0.0502131
# 	43001/50000: loss: 0.0038983 - mea: 0.0502080
# 	44001/50000: loss: 0.0038976 - mea: 0.0502031
# 	45001/50000: loss: 0.0038970 - mea: 0.0501992
# 	46001/50000: loss: 0.0038965 - mea: 0.0501960
# 	47001/50000: loss: 0.0038961 - mea: 0.0501934
# 	48001/50000: loss: 0.0038958 - mea: 0.0501912
# 	49001/50000: loss: 0.0038955 - mea: 0.0501891
# model_type: NAC
# function: div
# test_result: 0.05168096721172333
# normalized_test_result: 0.33093159394739
# <br/>Waiting for W&B process to finish, PID 925<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191953-t9gyv4yf/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_191953-t9gyv4yf/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.0039</td></tr><tr><td>mean_absolute_error</td><td>0.05019</td></tr><tr><td>_runtime</td><td>24</td></tr><tr><td>_timestamp</td><td>1623439217</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">div_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/t9gyv4yf" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/t9gyv4yf</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">div_Complex_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/Experiment_1" target="_blank">https://wandb.ai/galmitr/Experiment_1</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/Experiment_1/runs/db04fcfu" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/db04fcfu</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_192024-db04fcfu</code><br/><br/>
# 	1/50000: loss: 151.4924622 - mea: 11.9921055
# 	1001/50000: loss: 0.0384302 - mea: 0.1817961
# 	2001/50000: loss: 0.0189010 - mea: 0.1209432
# 	3001/50000: loss: 0.0123164 - mea: 0.0943413
# 	4001/50000: loss: 0.0092009 - mea: 0.0796465
# 	5001/50000: loss: 0.0075385 - mea: 0.0708008
# 	6001/50000: loss: 0.0065522 - mea: 0.0654130
# 	7001/50000: loss: 0.0059187 - mea: 0.0618472
# 	8001/50000: loss: 0.0054866 - mea: 0.0593323
# 	9001/50000: loss: 0.0051773 - mea: 0.0575228
# 	10001/50000: loss: 0.0049478 - mea: 0.0562022
# 	11001/50000: loss: 0.0047719 - mea: 0.0551690
# 	12001/50000: loss: 0.0046335 - mea: 0.0543634
# 	13001/50000: loss: 0.0045222 - mea: 0.0537049
# 	14001/50000: loss: 0.0044317 - mea: 0.0531589
# 	15001/50000: loss: 0.0043567 - mea: 0.0527129
# 	16001/50000: loss: 0.0042938 - mea: 0.0523470
# 	17001/50000: loss: 0.0042405 - mea: 0.0520467
# 	18001/50000: loss: 0.0041951 - mea: 0.0517868
# 	19001/50000: loss: 0.0041564 - mea: 0.0515605
# 	20001/50000: loss: 0.0041230 - mea: 0.0513643
# 	21001/50000: loss: 0.0040940 - mea: 0.0511945
# 	22001/50000: loss: 0.0040691 - mea: 0.0510470
# 	23001/50000: loss: 0.0040475 - mea: 0.0509179
# 	24001/50000: loss: 0.0040288 - mea: 0.0508079
# 	25001/50000: loss: 0.0040127 - mea: 0.0507098
# 	26001/50000: loss: 0.0039987 - mea: 0.0506237
# 	27001/50000: loss: 0.0039867 - mea: 0.0505536
# 	28001/50000: loss: 0.0039764 - mea: 0.0504948
# 	29001/50000: loss: 0.0039675 - mea: 0.0504434
# 	30001/50000: loss: 0.0039600 - mea: 0.0503992
# 	31001/50000: loss: 0.0039535 - mea: 0.0503618
# 	32001/50000: loss: 0.0039481 - mea: 0.0503311
# 	33001/50000: loss: 0.0039434 - mea: 0.0503041
# 	34001/50000: loss: 0.0039396 - mea: 0.0502817
# 	35001/50000: loss: 0.0039363 - mea: 0.0502622
# 	36001/50000: loss: 0.0039335 - mea: 0.0502459
# 	37001/50000: loss: 0.0039312 - mea: 0.0502325
# 	38001/50000: loss: 0.0039293 - mea: 0.0502208
# 	39001/50000: loss: 0.0039277 - mea: 0.0502114
# 	40001/50000: loss: 0.0039263 - mea: 0.0502031
# 	41001/50000: loss: 0.0039251 - mea: 0.0501959
# 	42001/50000: loss: 0.0039242 - mea: 0.0501900
# 	43001/50000: loss: 0.0039234 - mea: 0.0501853
# 	44001/50000: loss: 0.0039228 - mea: 0.0501817
# 	45001/50000: loss: 0.0039223 - mea: 0.0501782
# 	46001/50000: loss: 0.0039218 - mea: 0.0501753
# 	47001/50000: loss: 0.0039214 - mea: 0.0501731
# 	48001/50000: loss: 0.0039211 - mea: 0.0501711
# 	49001/50000: loss: 0.0039209 - mea: 0.0501700
# model_type: Complex_NAC
# function: div
# test_result: 0.04785019904375076
# normalized_test_result: 0.5150316659936383
# <br/>Waiting for W&B process to finish, PID 967<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_192024-db04fcfu/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_192024-db04fcfu/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.00392</td></tr><tr><td>mean_absolute_error</td><td>0.05017</td></tr><tr><td>_runtime</td><td>24</td></tr><tr><td>_timestamp</td><td>1623439248</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">div_Complex_NAC</strong>: <a href="https://wandb.ai/galmitr/Experiment_1/runs/db04fcfu" target="_blank">https://wandb.ai/galmitr/Experiment_1/runs/db04fcfu</a><br/>

# %% [markdown]
# ### Wandb pipeline

# %%
"""
pipeline for training model and tracking weights, gradients and metrics via Wandb
"""

def model_pipeline(hyperparameters):
    with wandb.init(project=f"{hyperparameters['project']}",
                    group=f"{hyperparameters['function']}", 
                    job_type=f"{hyperparameters['model']}",
                    name=f"{hyperparameters['function']}_{hyperparameters['model']}",
                    tags=f"{hyperparameters['tags']}",
                    config=hyperparameters):
        config = wandb.config

        random_model, model, data, criterion, optimizer = make(config)
        # print(model)

        # data
        train_data, test_data = data
 
        # random_model
        random_mea = []
        for i in range(100):
            abs = test(random_model, test_data)
            random_mea.append(abs.mean().item())
        random_result = np.mean(random_mea)

        # model
        train(model, 
            train_data,
            criterion, 
            optimizer,
            config.NUM_ITERS)
        
        abs = test(model, test_data)
        result = abs.mean().item()
        normalized_result = 100.0 * result/random_result

        print('model_type:', config.model)
        print('function:', config.function)
        print('test_result:', result)
        print('normalized_test_result:', normalized_result)

        ###wand plots
        # id = FUNC_id[config.function]

        table_res = wandb.Table(data=[[config.function, result]], 
                                columns=["FUNCTION", "Mean_of_MAE"])
        
        table_norm_res = wandb.Table(data=[[config.function, normalized_result]], 
                                     columns=["FUNCTION", "Scaled_Mean_of_MAE"])

        wandb.log({
        'Results': wandb.plot.bar(table_res, 
                                "FUNCTION",
                                "Mean_of_MAE",
                                title="Results"),
                   
        'Normalized_Results': wandb.plot.bar(table_norm_res, 
                                            "FUNCTION",
                                            "Scaled_Mean_of_MAE", 
                                            title="Normalized_Results")
        })

    return model


def make(config):
    # Make the model
    model = MODELS[config.model](config.NUM_LAYERS, 
                                config.in_dim, 
                                config.HIDDEN_DIM, 
                                config.out_dim).model

    random_model = MLP(config.NUM_LAYERS, 
                        config.in_dim, 
                        config.HIDDEN_DIM, 
                        config.out_dim).model

    # Make the data
    data = generate_data(config.function,
                         config.num_train, 
                         config.num_test, 
                         config.dim, 
                         config.num_sum, 
                         config.RANGE)
    
    # Make the loss and optimizer
    criterion = F.mse_loss
    optimizer = torch.optim.RMSprop(model.parameters(), lr=config.LEARNING_RATE)

    # return random_model, model, criterion, optimizer
    return random_model, model, data, criterion, optimizer


def generate_data(function, num_train, num_test, dim, num_sum, support):

    fn = ARITHMETIC_FUNCTIONS[function]
    data = torch.FloatTensor(dim).uniform_(*support).unsqueeze_(1)
    X, y = [], []
    for i in range(num_train + num_test):
        idx_a = random.sample(range(dim), num_sum)
        idx_b = random.sample([x for x in range(dim) if x not in idx_a], num_sum)
        a, b = data[idx_a].sum(), data[idx_b].sum()
        X.append([a, b])
        y.append(fn(a, b))
    X = torch.FloatTensor(X)
    y = torch.FloatTensor(y).unsqueeze_(1)
    indices = list(range(num_train + num_test))
    np.random.shuffle(indices)
    X_train, y_train = X[indices[num_test:]], y[indices[num_test:]]
    X_test, y_test = X[indices[:num_test]], y[indices[:num_test]]

    return ((X_train, y_train), (X_test, y_test))


def train(model, train_data, criterion, optimizer, num_iters):
    wandb.watch(model, criterion, log="all", log_freq=1000)

    data, target = train_data
    # model.train()
    for i in range(num_iters):
        out = model(data)
        loss = criterion(out, target)
        mea = torch.mean(torch.abs(target - out))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if i % 1000 == 0:
            train_log(loss, mea, i, num_iters)

def train_log(loss, mea, epoch, num_iters):
    wandb.log({"epoch": epoch, "loss_(mse)": loss.item(), 'mean_absolute_error': mea.item()})
    print("\t{}/{}: loss: {:.7f} - mea: {:.7f}".format(epoch+1, num_iters, loss.item(), mea.item()))


def test(model, test_data):
    data, target = test_data
    with torch.no_grad():
        out = model(data)
        return torch.abs(target - out)

# %% [markdown]
# ### Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
PATH_TO_FOLDER = '/content/drive/MyDrive/DL_project/EXPERIMENTS'

# %%
# %cd {PATH_TO_FOLDER}
# Out:
# /content/drive/MyDrive/DL_project/EXPERIMENTS

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from models import MLP, NAC, NALU

# %%
import math
import random
import numpy as np
from tqdm.notebook import tqdm
from copy import deepcopy

import torch
import torch.nn as nn
import torch.nn.functional as F

# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)

# Device configuration
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# %%capture
# !pip install wandb --upgrade

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ### INTERPOLATION Parameters

# %%
NAMES = dict(
    project = 'INTERPOLATION',
    tags = 'preparation'
)

MODEL_PARAMETERS = dict(
    in_dim=2,
    out_dim=1,
    NUM_LAYERS = 2,
    HIDDEN_DIM = 2,
)

ARITHMETIC_PARAMETERS = dict(
    num_train=500, 
    num_test=50,
    dim=100, 
    num_sum=5,
    RANGE = [5, 10]
)

TRAIN_PARAMETERS = dict(
                        LEARNING_RATE = 1e-2,
                        # NUM_ITERS = int(1e5),
                        NUM_ITERS = int(50000),
                        activation='relu6'
                        )

ARITHMETIC_FUNCTIONS = {
    'add': lambda x, y: x + y,
    'sub': lambda x, y: x - y,
    'mul': lambda x, y: x * y,
    'div': lambda x, y: x / y,
    'squared': lambda x, y: torch.pow(x, 2),
    'root': lambda x, y: torch.sqrt(x)
    }

MODELS = {
        'MLP': MLP, 
        'NAC': NAC, 
        'NALU': NALU
        }

# %%
# def get_id():
#     id_dct = {}
#     for i, key in enumerate(ARITHMETIC_FUNCTIONS.keys()):
#         id_dct[key] = i
#     return id_dct

# FUNC_id = get_id()

# %% [markdown]
# ### Config for Wandb

# %%
def create_config(model, function):
    config = {'model': model,
              'function': function}
              
    models = MODEL_PARAMETERS.copy()
    funcs = ARITHMETIC_PARAMETERS.copy()
    params = TRAIN_PARAMETERS.copy()
    names = NAMES.copy()

    for key, value in models.items():
        config[key] = value
    for key, value in funcs.items():
        config[key] = value
    for key, value in params.items():
        config[key] = value
    for key, value in names.items():
        config[key] = value

    return config

# %% [markdown]
# ### Example of config

# %%
config = create_config('MLP', 'add')

# %%
config
# Out:
# {'HIDDEN_DIM': 2,
#  'LEARNING_RATE': 0.01,
#  'NUM_ITERS': 50000,
#  'NUM_LAYERS': 2,
#  'RANGE': [5, 10],
#  'activation': 'relu6',
#  'dim': 100,
#  'function': 'add',
#  'in_dim': 2,
#  'model': 'MLP',
#  'num_sum': 5,
#  'num_test': 50,
#  'num_train': 500,
#  'out_dim': 1,
#  'project': 'INTERPOLATION',
#  'tags': 'preparation'}

# %% [markdown]
# ### Iteration on models and arithmetic functions

# %%
mdls = MODELS.keys()
fncts = ARITHMETIC_FUNCTIONS.keys()

for function in fncts:
    for arch in mdls:
        config = create_config(arch, function)
        # Build, train and analyze the model with the pipeline
        model = model_pipeline(config)
# Out:
# wandb: Currently logged in as: galmitr (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">add_MLP</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/2ke9tmp3" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/2ke9tmp3</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_192912-2ke9tmp3</code><br/><br/>
# 	1/50000: loss: 3748.6340332 - mea: 61.1039314
# 	1001/50000: loss: 0.7828440 - mea: 0.8812203
# 	2001/50000: loss: 0.5584386 - mea: 0.7453416
# 	3001/50000: loss: 0.5582510 - mea: 0.7457025
# 	4001/50000: loss: 0.5568953 - mea: 0.7451655
# 	5001/50000: loss: 0.5557318 - mea: 0.7446712
# 	6001/50000: loss: 0.5547053 - mea: 0.7442012
# 	7001/50000: loss: 0.5537956 - mea: 0.7437565
# 	8001/50000: loss: 0.5529677 - mea: 0.7433252
# 	9001/50000: loss: 0.5522817 - mea: 0.7429571
# 	10001/50000: loss: 0.5516057 - mea: 0.7425703
# 	11001/50000: loss: 0.5510343 - mea: 0.7422344
# 	12001/50000: loss: 0.5506465 - mea: 0.7420072
# 	13001/50000: loss: 0.5501085 - mea: 0.7416670
# 	14001/50000: loss: 0.5497105 - mea: 0.7414125
# 	15001/50000: loss: 0.5493234 - mea: 0.7411587
# 	16001/50000: loss: 0.5489950 - mea: 0.7409395
# 	17001/50000: loss: 0.5485813 - mea: 0.7406591
# 	18001/50000: loss: 0.5482658 - mea: 0.7404423
# 	19001/50000: loss: 0.5478176 - mea: 0.7401340
# 	20001/50000: loss: 0.5476298 - mea: 0.7400004
# 	21001/50000: loss: 0.5474004 - mea: 0.7398377
# 	22001/50000: loss: 0.5472719 - mea: 0.7397431
# 	23001/50000: loss: 0.5467929 - mea: 0.7394111
# 	24001/50000: loss: 0.5466459 - mea: 0.7393038
# 	25001/50000: loss: 0.5463116 - mea: 0.7390699
# 	26001/50000: loss: 0.5461068 - mea: 0.7389238
# 	27001/50000: loss: 0.5458756 - mea: 0.7387602
# 	28001/50000: loss: 0.5457909 - mea: 0.7386960
# 	29001/50000: loss: 0.5455371 - mea: 0.7385178
# 	30001/50000: loss: 0.5451777 - mea: 0.7382686
# 	31001/50000: loss: 0.5449894 - mea: 0.7381355
# 	32001/50000: loss: 0.5448212 - mea: 0.7380164
# 	33001/50000: loss: 0.5445426 - mea: 0.7378229
# 	34001/50000: loss: 0.5442860 - mea: 0.7376447
# 	35001/50000: loss: 0.5439905 - mea: 0.7374403
# 	36001/50000: loss: 0.5440496 - mea: 0.7374765
# 	37001/50000: loss: 0.5439086 - mea: 0.7373773
# 	38001/50000: loss: 0.5435162 - mea: 0.7371082
# 	39001/50000: loss: 0.5433077 - mea: 0.7369639
# 	40001/50000: loss: 0.5430859 - mea: 0.7368108
# 	41001/50000: loss: 0.5429876 - mea: 0.7367416
# 	42001/50000: loss: 0.5427278 - mea: 0.7365631
# 	43001/50000: loss: 0.5425282 - mea: 0.7364255
# 	44001/50000: loss: 0.5424030 - mea: 0.7363385
# 	45001/50000: loss: 0.5422081 - mea: 0.7362046
# 	46001/50000: loss: 0.5420426 - mea: 0.7360905
# 	47001/50000: loss: 0.5417811 - mea: 0.7359114
# 	48001/50000: loss: 0.5416481 - mea: 0.7358197
# 	49001/50000: loss: 0.5413830 - mea: 0.7356383
# model_type: MLP
# function: add
# test_result: 0.7328316569328308
# normalized_test_result: 1.0094472513776505
# <br/>Waiting for W&B process to finish, PID 392<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_192912-2ke9tmp3/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_192912-2ke9tmp3/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.54138</td></tr><tr><td>mean_absolute_error</td><td>0.73564</td></tr><tr><td>_runtime</td><td>30</td></tr><tr><td>_timestamp</td><td>1623439782</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">add_MLP</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/2ke9tmp3" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/2ke9tmp3</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">add_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/21q40lzq" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/21q40lzq</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_192949-21q40lzq</code><br/><br/>
# 	1/50000: loss: 7029.0747070 - mea: 83.6875458
# 	1001/50000: loss: 0.0033662 - mea: 0.0468918
# 	2001/50000: loss: 0.0192659 - mea: 0.1385377
# 	3001/50000: loss: 0.0172079 - mea: 0.1308930
# 	4001/50000: loss: 0.0145552 - mea: 0.1203790
# 	5001/50000: loss: 0.0122746 - mea: 0.1105449
# 	6001/50000: loss: 0.0103421 - mea: 0.1014696
# 	7001/50000: loss: 0.0087115 - mea: 0.0931267
# 	8001/50000: loss: 0.0073053 - mea: 0.0852791
# 	9001/50000: loss: 0.0061372 - mea: 0.0781640
# 	10001/50000: loss: 0.0051513 - mea: 0.0716105
# 	11001/50000: loss: 0.0043264 - mea: 0.0656273
# 	12001/50000: loss: 0.0036246 - mea: 0.0600686
# 	13001/50000: loss: 0.0030399 - mea: 0.0550108
# 	14001/50000: loss: 0.0025570 - mea: 0.0504529
# 	15001/50000: loss: 0.0021463 - mea: 0.0462238
# 	16001/50000: loss: 0.0017937 - mea: 0.0422569
# 	17001/50000: loss: 0.0015088 - mea: 0.0387558
# 	18001/50000: loss: 0.0012754 - mea: 0.0356329
# 	19001/50000: loss: 0.0010640 - mea: 0.0325461
# 	20001/50000: loss: 0.0008965 - mea: 0.0298743
# 	21001/50000: loss: 0.0007569 - mea: 0.0274490
# 	22001/50000: loss: 0.0006320 - mea: 0.0250834
# 	23001/50000: loss: 0.0005347 - mea: 0.0230720
# 	24001/50000: loss: 0.0004446 - mea: 0.0210378
# 	25001/50000: loss: 0.0003717 - mea: 0.0192354
# 	26001/50000: loss: 0.0003171 - mea: 0.0177668
# 	27001/50000: loss: 0.0002648 - mea: 0.0162370
# 	28001/50000: loss: 0.0002223 - mea: 0.0148754
# 	29001/50000: loss: 0.0001855 - mea: 0.0135888
# 	30001/50000: loss: 0.0001535 - mea: 0.0123634
# 	31001/50000: loss: 0.0001328 - mea: 0.0115002
# 	32001/50000: loss: 0.0001096 - mea: 0.0104457
# 	33001/50000: loss: 0.0000909 - mea: 0.0095107
# 	34001/50000: loss: 0.0000775 - mea: 0.0087814
# 	35001/50000: loss: 0.0000636 - mea: 0.0079585
# 	36001/50000: loss: 0.0000547 - mea: 0.0073761
# 	37001/50000: loss: 0.0000446 - mea: 0.0066671
# 	38001/50000: loss: 0.0000381 - mea: 0.0061614
# 	39001/50000: loss: 0.0000317 - mea: 0.0056165
# 	40001/50000: loss: 0.0000269 - mea: 0.0051724
# 	41001/50000: loss: 0.0000212 - mea: 0.0045967
# 	42001/50000: loss: 0.0000191 - mea: 0.0043584
# 	43001/50000: loss: 0.0000158 - mea: 0.0039614
# 	44001/50000: loss: 0.0000138 - mea: 0.0037033
# 	45001/50000: loss: 0.0000102 - mea: 0.0031821
# 	46001/50000: loss: 0.0000094 - mea: 0.0030579
# 	47001/50000: loss: 0.0000076 - mea: 0.0027462
# 	48001/50000: loss: 0.0000062 - mea: 0.0024767
# 	49001/50000: loss: 0.0000049 - mea: 0.0022041
# model_type: NAC
# function: add
# test_result: 0.0020678711589425802
# normalized_test_result: 0.0026622367615254335
# <br/>Waiting for W&B process to finish, PID 435<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_192949-21q40lzq/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_192949-21q40lzq/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.0</td></tr><tr><td>mean_absolute_error</td><td>0.0022</td></tr><tr><td>_runtime</td><td>31</td></tr><tr><td>_timestamp</td><td>1623439820</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">add_NAC</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/21q40lzq" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/21q40lzq</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">add_NALU</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/4yp9du5n" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/4yp9du5n</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193026-4yp9du5n</code><br/><br/>
# 	1/50000: loss: 6646.0751953 - mea: 81.3788605
# 	1001/50000: loss: 4.0522738 - mea: 1.7092155
# 	2001/50000: loss: 3.2490234 - mea: 1.5538594
# 	3001/50000: loss: 2.9144080 - mea: 1.4764096
# 	4001/50000: loss: 2.7402048 - mea: 1.4300343
# 	5001/50000: loss: 2.6239080 - mea: 1.3969358
# 	6001/50000: loss: 2.5313683 - mea: 1.3701613
# 	7001/50000: loss: 2.4506972 - mea: 1.3464513
# 	8001/50000: loss: 2.3807337 - mea: 1.3256232
# 	9001/50000: loss: 2.3169265 - mea: 1.3063997
# 	10001/50000: loss: 2.2611101 - mea: 1.2894981
# 	11001/50000: loss: 2.2094994 - mea: 1.2736760
# 	12001/50000: loss: 2.1640484 - mea: 1.2596492
# 	13001/50000: loss: 2.1223688 - mea: 1.2466543
# 	14001/50000: loss: 2.0868485 - mea: 1.2355886
# 	15001/50000: loss: 2.0543647 - mea: 1.2253973
# 	16001/50000: loss: 2.0255828 - mea: 1.2163492
# 	17001/50000: loss: 2.0002713 - mea: 1.2083992
# 	18001/50000: loss: 1.9777086 - mea: 1.2013171
# 	19001/50000: loss: 1.9572546 - mea: 1.1948935
# 	20001/50000: loss: 1.9391894 - mea: 1.1892518
# 	21001/50000: loss: 1.9236225 - mea: 1.1844485
# 	22001/50000: loss: 1.9093069 - mea: 1.1800404
# 	23001/50000: loss: 1.8958215 - mea: 1.1758807
# 	24001/50000: loss: 1.8848665 - mea: 1.1726080
# 	25001/50000: loss: 1.8744626 - mea: 1.1694951
# 	26001/50000: loss: 1.8650490 - mea: 1.1667112
# 	27001/50000: loss: 1.8565557 - mea: 1.1642334
# 	28001/50000: loss: 1.8489794 - mea: 1.1620637
# 	29001/50000: loss: 1.8426768 - mea: 1.1603401
# 	30001/50000: loss: 1.8363569 - mea: 1.1585791
# 	31001/50000: loss: 1.8298911 - mea: 1.1567345
# 	32001/50000: loss: 1.8247781 - mea: 1.1553692
# 	33001/50000: loss: 1.8200526 - mea: 1.1541308
# 	34001/50000: loss: 1.8159267 - mea: 1.1530945
# 	35001/50000: loss: 1.8113357 - mea: 1.1518548
# 	36001/50000: loss: 1.8076279 - mea: 1.1509216
# 	37001/50000: loss: 1.8038442 - mea: 1.1499336
# 	38001/50000: loss: 1.8009214 - mea: 1.1492449
# 	39001/50000: loss: 1.7978972 - mea: 1.1484913
# 	40001/50000: loss: 1.7944026 - mea: 1.1475353
# 	41001/50000: loss: 1.7919182 - mea: 1.1469665
# 	42001/50000: loss: 1.7896268 - mea: 1.1464576
# 	43001/50000: loss: 1.7872419 - mea: 1.1459160
# 	44001/50000: loss: 1.7840261 - mea: 1.1450294
# 	45001/50000: loss: 1.7825259 - mea: 1.1447802
# 	46001/50000: loss: 1.7809930 - mea: 1.1444942
# 	47001/50000: loss: 1.7788765 - mea: 1.1439607
# 	48001/50000: loss: 1.7776331 - mea: 1.1437418
# 	49001/50000: loss: 1.7764161 - mea: 1.1435122
# model_type: NALU
# function: add
# test_result: 1.0060352087020874
# normalized_test_result: 1.821059639637114
# <br/>Waiting for W&B process to finish, PID 475<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193026-4yp9du5n/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193026-4yp9du5n/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>1.77642</td></tr><tr><td>mean_absolute_error</td><td>1.14351</td></tr><tr><td>_runtime</td><td>68</td></tr><tr><td>_timestamp</td><td>1623439894</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">add_NALU</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/4yp9du5n" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/4yp9du5n</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">sub_MLP</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/26rh6fl2" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/26rh6fl2</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193139-26rh6fl2</code><br/><br/>
# 	1/50000: loss: 18.4325676 - mea: 3.3782134
# 	1001/50000: loss: 18.1327953 - mea: 3.3373244
# 	2001/50000: loss: 18.1327953 - mea: 3.3373239
# 	3001/50000: loss: 18.1327953 - mea: 3.3373239
# 	4001/50000: loss: 18.1327972 - mea: 3.3373239
# 	5001/50000: loss: 18.1327953 - mea: 3.3373246
# 	6001/50000: loss: 18.1327953 - mea: 3.3373239
# 	7001/50000: loss: 18.1327953 - mea: 3.3373239
# 	8001/50000: loss: 18.1327953 - mea: 3.3373241
# 	9001/50000: loss: 18.1327953 - mea: 3.3373258
# 	10001/50000: loss: 18.1327953 - mea: 3.3373239
# 	11001/50000: loss: 18.1327953 - mea: 3.3373239
# 	12001/50000: loss: 18.1327953 - mea: 3.3373241
# 	13001/50000: loss: 18.1327953 - mea: 3.3373287
# 	14001/50000: loss: 18.1327953 - mea: 3.3373239
# 	15001/50000: loss: 18.1327953 - mea: 3.3373239
# 	16001/50000: loss: 18.1327953 - mea: 3.3373241
# 	17001/50000: loss: 18.1327953 - mea: 3.3373356
# 	18001/50000: loss: 18.1327953 - mea: 3.3373239
# 	19001/50000: loss: 18.1327953 - mea: 3.3373239
# 	20001/50000: loss: 18.1327953 - mea: 3.3373241
# 	21001/50000: loss: 18.1327953 - mea: 3.3373568
# 	22001/50000: loss: 18.1327953 - mea: 3.3373239
# 	23001/50000: loss: 18.1327953 - mea: 3.3373239
# 	24001/50000: loss: 18.1327953 - mea: 3.3373241
# 	25001/50000: loss: 18.1328049 - mea: 3.3374169
# 	26001/50000: loss: 18.1327953 - mea: 3.3373239
# 	27001/50000: loss: 18.1327953 - mea: 3.3373239
# 	28001/50000: loss: 18.1327953 - mea: 3.3373241
# 	29001/50000: loss: 18.1328678 - mea: 3.3375959
# 	30001/50000: loss: 18.1327953 - mea: 3.3373239
# 	31001/50000: loss: 18.1327953 - mea: 3.3373239
# 	32001/50000: loss: 18.1327953 - mea: 3.3373241
# 	33001/50000: loss: 18.1333218 - mea: 3.3381143
# 	34001/50000: loss: 18.1327953 - mea: 3.3373239
# 	35001/50000: loss: 18.1327953 - mea: 3.3373239
# 	36001/50000: loss: 18.1327953 - mea: 3.3373241
# 	37001/50000: loss: 18.1336384 - mea: 3.3383565
# 	38001/50000: loss: 18.1327953 - mea: 3.3373239
# 	39001/50000: loss: 18.1327953 - mea: 3.3373239
# 	40001/50000: loss: 18.1327953 - mea: 3.3373241
# 	41001/50000: loss: 18.1328926 - mea: 3.3376439
# 	42001/50000: loss: 18.1327953 - mea: 3.3373239
# 	43001/50000: loss: 18.1327953 - mea: 3.3373239
# 	44001/50000: loss: 18.1327953 - mea: 3.3373241
# 	45001/50000: loss: 18.1328011 - mea: 3.3374009
# 	46001/50000: loss: 18.1327972 - mea: 3.3373239
# 	47001/50000: loss: 18.1327953 - mea: 3.3373239
# 	48001/50000: loss: 18.1327953 - mea: 3.3373241
# 	49001/50000: loss: 18.1327972 - mea: 3.3373425
# model_type: MLP
# function: sub
# test_result: 3.2459828853607178
# normalized_test_result: 100.82208277656937
# <br/>Waiting for W&B process to finish, PID 519<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193139-26rh6fl2/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193139-26rh6fl2/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>18.1328</td></tr><tr><td>mean_absolute_error</td><td>3.33734</td></tr><tr><td>_runtime</td><td>30</td></tr><tr><td>_timestamp</td><td>1623439929</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sub_MLP</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/26rh6fl2" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/26rh6fl2</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">sub_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/p3j6atw6" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/p3j6atw6</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193215-p3j6atw6</code><br/><br/>
# 	1/50000: loss: 25.3872166 - mea: 4.1018472
# 	1001/50000: loss: 0.0486156 - mea: 0.2201203
# 	2001/50000: loss: 0.0467388 - mea: 0.2158303
# 	3001/50000: loss: 0.0434900 - mea: 0.2081955
# 	4001/50000: loss: 0.0403792 - mea: 0.2006122
# 	5001/50000: loss: 0.0373849 - mea: 0.1930315
# 	6001/50000: loss: 0.0345214 - mea: 0.1854921
# 	7001/50000: loss: 0.0317472 - mea: 0.1778826
# 	8001/50000: loss: 0.0291351 - mea: 0.1704076
# 	9001/50000: loss: 0.0266530 - mea: 0.1629862
# 	10001/50000: loss: 0.0243147 - mea: 0.1556714
# 	11001/50000: loss: 0.0221169 - mea: 0.1484678
# 	12001/50000: loss: 0.0200971 - mea: 0.1415242
# 	13001/50000: loss: 0.0181970 - mea: 0.1346653
# 	14001/50000: loss: 0.0164687 - mea: 0.1281077
# 	15001/50000: loss: 0.0148859 - mea: 0.1217930
# 	16001/50000: loss: 0.0134380 - mea: 0.1157146
# 	17001/50000: loss: 0.0121231 - mea: 0.1099033
# 	18001/50000: loss: 0.0109287 - mea: 0.1043444
# 	19001/50000: loss: 0.0098426 - mea: 0.0990191
# 	20001/50000: loss: 0.0088560 - mea: 0.0939199
# 	21001/50000: loss: 0.0079617 - mea: 0.0890453
# 	22001/50000: loss: 0.0071466 - mea: 0.0843570
# 	23001/50000: loss: 0.0064073 - mea: 0.0798660
# 	24001/50000: loss: 0.0057350 - mea: 0.0755481
# 	25001/50000: loss: 0.0056190 - mea: 0.0724197
# 	26001/50000: loss: 0.0040249 - mea: 0.0619146
# 	27001/50000: loss: 0.0044297 - mea: 0.0653659
# 	28001/50000: loss: 0.0041178 - mea: 0.0635141
# 	29001/50000: loss: 0.0037000 - mea: 0.0606299
# 	30001/50000: loss: 0.0034716 - mea: 0.0586180
# 	31001/50000: loss: 0.0033130 - mea: 0.0569967
# 	32001/50000: loss: 0.0028629 - mea: 0.0528911
# 	33001/50000: loss: 0.0028501 - mea: 0.0509848
# 	34001/50000: loss: 0.0027557 - mea: 0.0520903
# 	35001/50000: loss: 0.0024379 - mea: 0.0476416
# 	36001/50000: loss: 0.0024073 - mea: 0.0475245
# 	37001/50000: loss: 0.0023027 - mea: 0.0444466
# 	38001/50000: loss: 0.0019779 - mea: 0.0418519
# 	39001/50000: loss: 0.0016763 - mea: 0.0389742
# 	40001/50000: loss: 0.0018247 - mea: 0.0409833
# 	41001/50000: loss: 0.0016056 - mea: 0.0388420
# 	42001/50000: loss: 0.0015586 - mea: 0.0374372
# 	43001/50000: loss: 0.0013388 - mea: 0.0345548
# 	44001/50000: loss: 0.0012889 - mea: 0.0336123
# 	45001/50000: loss: 0.0010042 - mea: 0.0309940
# 	46001/50000: loss: 0.0010497 - mea: 0.0314909
# 	47001/50000: loss: 0.0010348 - mea: 0.0321191
# 	48001/50000: loss: 0.0007949 - mea: 0.0280769
# 	49001/50000: loss: 0.0007669 - mea: 0.0267973
# model_type: NAC
# function: sub
# test_result: 0.025362152606248856
# normalized_test_result: 0.2080958544927732
# <br/>Waiting for W&B process to finish, PID 559<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193215-p3j6atw6/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193215-p3j6atw6/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.00077</td></tr><tr><td>mean_absolute_error</td><td>0.0268</td></tr><tr><td>_runtime</td><td>31</td></tr><tr><td>_timestamp</td><td>1623439966</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sub_NAC</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/p3j6atw6" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/p3j6atw6</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">sub_NALU</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/42te0zyf" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/42te0zyf</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193253-42te0zyf</code><br/><br/>
# 	1/50000: loss: 22.4865017 - mea: 3.7758424
# 	1001/50000: loss: 0.2037984 - mea: 0.3668483
# 	2001/50000: loss: 0.0665022 - mea: 0.2574056
# 	3001/50000: loss: 0.0590744 - mea: 0.2426206
# 	4001/50000: loss: 0.0519254 - mea: 0.2274517
# 	5001/50000: loss: 0.0451130 - mea: 0.2119971
# 	6001/50000: loss: 0.0387936 - mea: 0.1965779
# 	7001/50000: loss: 0.0330766 - mea: 0.1815040
# 	8001/50000: loss: 0.0279663 - mea: 0.1668834
# 	9001/50000: loss: 0.0235231 - mea: 0.1530434
# 	10001/50000: loss: 0.0197337 - mea: 0.1401680
# 	11001/50000: loss: 0.0030795 - mea: 0.0553668
# 	12001/50000: loss: 0.0122014 - mea: 0.1101981
# 	13001/50000: loss: 0.0205045 - mea: 0.1429334
# 	14001/50000: loss: 0.0064773 - mea: 0.0803305
# 	15001/50000: loss: 0.0011850 - mea: 0.0342368
# 	16001/50000: loss: 0.0101581 - mea: 0.1005121
# 	17001/50000: loss: 0.0000000 - mea: 0.0000391
# 	18001/50000: loss: 0.0042506 - mea: 0.0650726
# 	19001/50000: loss: 0.0004193 - mea: 0.0204363
# 	20001/50000: loss: 0.0043593 - mea: 0.0659057
# 	21001/50000: loss: 0.0044185 - mea: 0.0662980
# 	22001/50000: loss: 0.0043046 - mea: 0.0654813
# 	23001/50000: loss: 0.0032511 - mea: 0.0568628
# 	24001/50000: loss: 0.0032191 - mea: 0.0565736
# 	25001/50000: loss: 0.0010716 - mea: 0.0320556
# 	26001/50000: loss: 0.0019637 - mea: 0.0442163
# 	27001/50000: loss: 0.0028886 - mea: 0.0536196
# 	28001/50000: loss: 0.0015375 - mea: 0.0389484
# 	29001/50000: loss: 0.0012970 - mea: 0.0357667
# 	30001/50000: loss: 0.0000064 - mea: 0.0025186
# 	31001/50000: loss: 0.0010936 - mea: 0.0329114
# 	32001/50000: loss: 0.0011734 - mea: 0.0341101
# 	33001/50000: loss: 0.0006995 - mea: 0.0263017
# 	34001/50000: loss: 0.0007952 - mea: 0.0280725
# 	35001/50000: loss: 0.0007137 - mea: 0.0266041
# 	36001/50000: loss: 0.0006478 - mea: 0.0253551
# 	37001/50000: loss: 0.0005660 - mea: 0.0237039
# 	38001/50000: loss: 0.0004836 - mea: 0.0219095
# 	39001/50000: loss: 0.0004586 - mea: 0.0213365
# 	40001/50000: loss: 0.0004124 - mea: 0.0202345
# 	41001/50000: loss: 0.0003698 - mea: 0.0191619
# 	42001/50000: loss: 0.0003311 - mea: 0.0181338
# 	43001/50000: loss: 0.0002949 - mea: 0.0171072
# 	44001/50000: loss: 0.0002674 - mea: 0.0162916
# 	45001/50000: loss: 0.0002415 - mea: 0.0154822
# 	46001/50000: loss: 0.0002169 - mea: 0.0146768
# 	47001/50000: loss: 0.0002011 - mea: 0.0141314
# 	48001/50000: loss: 0.0001765 - mea: 0.0132353
# 	49001/50000: loss: 0.0001580 - mea: 0.0125258
# model_type: NALU
# function: sub
# test_result: 0.011822061613202095
# normalized_test_result: 0.3265252225687824
# <br/>Waiting for W&B process to finish, PID 601<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193253-42te0zyf/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193253-42te0zyf/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.00016</td></tr><tr><td>mean_absolute_error</td><td>0.01253</td></tr><tr><td>_runtime</td><td>62</td></tr><tr><td>_timestamp</td><td>1623440035</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sub_NALU</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/42te0zyf" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/42te0zyf</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">mul_MLP</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/2av24rm4" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/2av24rm4</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193401-2av24rm4</code><br/><br/>
# 	1/50000: loss: 1739532.7500000 - mea: 1310.4144287
# 	1001/50000: loss: 5681.9067383 - mea: 60.9020309
# 	2001/50000: loss: 5306.3750000 - mea: 59.0105209
# 	3001/50000: loss: 4885.9179688 - mea: 56.6304131
# 	4001/50000: loss: 4385.9853516 - mea: 53.6638374
# 	5001/50000: loss: 3761.4389648 - mea: 49.7087173
# 	6001/50000: loss: 3006.5122070 - mea: 44.4476166
# 	7001/50000: loss: 2203.7224121 - mea: 38.0566406
# 	8001/50000: loss: 1490.6488037 - mea: 31.3604755
# 	9001/50000: loss: 957.5733032 - mea: 25.2971859
# 	10001/50000: loss: 609.9528198 - mea: 20.4424419
# 	11001/50000: loss: 404.7455750 - mea: 16.9190769
# 	12001/50000: loss: 291.8048096 - mea: 14.5704603
# 	13001/50000: loss: 232.5429993 - mea: 13.0552673
# 	14001/50000: loss: 202.3949127 - mea: 12.1663904
# 	15001/50000: loss: 187.3672333 - mea: 11.6691628
# 	16001/50000: loss: 179.9253082 - mea: 11.4099178
# 	17001/50000: loss: 176.2155304 - mea: 11.2775402
# 	18001/50000: loss: 174.3334808 - mea: 11.2091894
# 	19001/50000: loss: 173.3127899 - mea: 11.1657324
# 	20001/50000: loss: 172.7119598 - mea: 11.1378498
# 	21001/50000: loss: 172.3674622 - mea: 11.1218243
# 	22001/50000: loss: 172.0540314 - mea: 11.1077652
# 	23001/50000: loss: 171.8448029 - mea: 11.0977621
# 	24001/50000: loss: 171.6328735 - mea: 11.0877323
# 	25001/50000: loss: 171.4394073 - mea: 11.0787077
# 	26001/50000: loss: 171.2350769 - mea: 11.0695457
# 	27001/50000: loss: 171.0679016 - mea: 11.0621557
# 	28001/50000: loss: 170.8730164 - mea: 11.0537214
# 	29001/50000: loss: 170.6919403 - mea: 11.0459213
# 	30001/50000: loss: 170.5112000 - mea: 11.0382118
# 	31001/50000: loss: 170.3347778 - mea: 11.0307198
# 	32001/50000: loss: 170.1498871 - mea: 11.0229025
# 	33001/50000: loss: 169.9781189 - mea: 11.0156631
# 	34001/50000: loss: 169.8087463 - mea: 11.0085459
# 	35001/50000: loss: 169.6437378 - mea: 11.0016022
# 	36001/50000: loss: 169.4328613 - mea: 10.9927511
# 	37001/50000: loss: 169.2709351 - mea: 10.9859352
# 	38001/50000: loss: 169.1022797 - mea: 10.9788342
# 	39001/50000: loss: 168.9214935 - mea: 10.9712238
# 	40001/50000: loss: 168.7668304 - mea: 10.9646950
# 	41001/50000: loss: 168.5545502 - mea: 10.9557667
# 	42001/50000: loss: 168.4404449 - mea: 10.9509497
# 	43001/50000: loss: 168.2164612 - mea: 10.9415359
# 	44001/50000: loss: 168.0735626 - mea: 10.9355135
# 	45001/50000: loss: 167.9260406 - mea: 10.9292831
# 	46001/50000: loss: 167.7273865 - mea: 10.9209137
# 	47001/50000: loss: 167.5792236 - mea: 10.9146605
# 	48001/50000: loss: 167.3823090 - mea: 10.9063454
# 	49001/50000: loss: 167.2438507 - mea: 10.9004793
# model_type: MLP
# function: mul
# test_result: 10.991904258728027
# normalized_test_result: 0.8334450634082662
# <br/>Waiting for W&B process to finish, PID 643<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193401-2av24rm4/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193401-2av24rm4/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>167.24385</td></tr><tr><td>mean_absolute_error</td><td>10.90048</td></tr><tr><td>_runtime</td><td>30</td></tr><tr><td>_timestamp</td><td>1623440071</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">mul_MLP</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/2av24rm4" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/2av24rm4</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">mul_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/3839x5mz" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/3839x5mz</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193438-3839x5mz</code><br/><br/>
# 	1/50000: loss: 2009686.1250000 - mea: 1408.3637695
# 	1001/50000: loss: 1620627.1250000 - mea: 1263.7286377
# 	2001/50000: loss: 1619169.2500000 - mea: 1263.1557617
# 	3001/50000: loss: 1619147.5000000 - mea: 1263.1470947
# 	4001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	5001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	6001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	7001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	8001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	9001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	10001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	11001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	12001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	13001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	14001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	15001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	16001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	17001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	18001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	19001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	20001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	21001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	22001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	23001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	24001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	25001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	26001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	27001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	28001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	29001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	30001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	31001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	32001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	33001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	34001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	35001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	36001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	37001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	38001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	39001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	40001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	41001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	42001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	43001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	44001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	45001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	46001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	47001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	48001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# 	49001/50000: loss: 1619147.1250000 - mea: 1263.1470947
# model_type: NAC
# function: mul
# test_result: 1265.045654296875
# normalized_test_result: 89.17806822303523
# <br/>Waiting for W&B process to finish, PID 685<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193438-3839x5mz/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193438-3839x5mz/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>1619147.125</td></tr><tr><td>mean_absolute_error</td><td>1263.14709</td></tr><tr><td>_runtime</td><td>31</td></tr><tr><td>_timestamp</td><td>1623440109</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">mul_NAC</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/3839x5mz" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/3839x5mz</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">mul_NALU</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/3ioekoyr" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/3ioekoyr</a><br/>
#                 Run data is saved locally in <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193515-3ioekoyr</code><br/><br/>
# 	1/50000: loss: 2224618.0000000 - mea: 1482.8612061
# 	1001/50000: loss: 1294.9248047 - mea: 31.7436008
# 	2001/50000: loss: 1092.4796143 - mea: 29.1405411
# 	3001/50000: loss: 889.2701416 - mea: 26.1761169
# 	4001/50000: loss: 681.5133667 - mea: 23.0156956
# 	5001/50000: loss: 519.5241699 - mea: 20.9236870
# 	6001/50000: loss: 441.0010071 - mea: 19.9423676
# 	7001/50000: loss: 410.9433899 - mea: 19.4155045
# 	8001/50000: loss: 392.3776550 - mea: 18.9868240
# 	9001/50000: loss: 376.3796997 - mea: 18.5965900
# 	10001/50000: loss: 361.0455627 - mea: 18.2130718
# 	11001/50000: loss: 346.5305786 - mea: 17.8421993
# 	12001/50000: loss: 332.3478394 - mea: 17.4712925
# 	13001/50000: loss: 318.8890686 - mea: 17.1126614
# 	14001/50000: loss: 306.1312561 - mea: 16.7667389
# 	15001/50000: loss: 293.5495911 - mea: 16.4181786
# 	16001/50000: loss: 281.4149475 - mea: 16.0755157
# 	17001/50000: loss: 269.5126953 - mea: 15.7321749
# 	18001/50000: loss: 258.1751099 - mea: 15.3991833
# 	19001/50000: loss: 247.1514435 - mea: 15.0687199
# 	20001/50000: loss: 236.0939789 - mea: 14.7288561
# 	21001/50000: loss: 225.6785278 - mea: 14.4028864
# 	22001/50000: loss: 215.3019714 - mea: 14.0699120
# 	23001/50000: loss: 205.5037231 - mea: 13.7494116
# 	24001/50000: loss: 195.6507416 - mea: 13.4181576
# 	25001/50000: loss: 186.1131439 - mea: 13.0897818
# 	26001/50000: loss: 176.8802185 - mea: 12.7640018
# 	27001/50000: loss: 167.9194336 - mea: 12.4396753
# 	28001/50000: loss: 159.2909088 - mea: 12.1193848
# 	29001/50000: loss: 150.8123474 - mea: 11.7955599
# 	30001/50000: loss: 142.7671967 - mea: 11.4807138
# 	31001/50000: loss: 134.4544830 - mea: 11.1433344
# 	32001/50000: loss: 127.1638565 - mea: 10.8422098
# 	33001/50000: loss: 119.7000656 - mea: 10.5224180
# 	34001/50000: loss: 112.5536270 - mea: 10.2068205
# 	35001/50000: loss: 105.7274017 - mea: 9.8959532
# 	36001/50000: loss: 99.4896011 - mea: 9.6046152
# 	37001/50000: loss: 93.2266312 - mea: 9.3009043
# 	38001/50000: loss: 87.1928558 - mea: 8.9981012
# 	39001/50000: loss: 81.5522156 - mea: 8.7059622
# 	40001/50000: loss: 76.0923691 - mea: 8.4127073
# 	41001/50000: loss: 70.9736938 - mea: 8.1283722
# 	42001/50000: loss: 66.3853531 - mea: 7.8662658
# 	43001/50000: loss: 61.5211182 - mea: 7.5745616
# 	44001/50000: loss: 57.2023811 - mea: 7.3073888
# 	45001/50000: loss: 53.0900536 - mea: 7.0430589
# 	46001/50000: loss: 49.1408119 - mea: 6.7787247
# 	47001/50000: loss: 45.4646034 - mea: 6.5230627
# 	48001/50000: loss: 42.1472740 - mea: 6.2842155
# 	49001/50000: loss: 38.9266090 - mea: 6.0421414
# model_type: NALU
# function: mul
# test_result: 5.904609203338623
# normalized_test_result: 0.4121699820993159
# <br/>Waiting for W&B process to finish, PID 725<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193515-3ioekoyr/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/MyDrive/DL_project/EXPERIMENTS/wandb/run-20210611_193515-3ioekoyr/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>38.92661</td></tr><tr><td>mean_absolute_error</td><td>6.04214</td></tr><tr><td>_runtime</td><td>64</td></tr><tr><td>_timestamp</td><td>1623440179</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">mul_NALU</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/3ioekoyr" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/3ioekoyr</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">div_MLP</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/3q7ipk9k" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/3q7ipk9k</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_193625-3q7ipk9k</code><br/><br/>
# 	1/50000: loss: 0.4815880 - mea: 0.6818374
# 	1001/50000: loss: 0.0166857 - mea: 0.1013899
# 	2001/50000: loss: 0.0166857 - mea: 0.1013927
# 	3001/50000: loss: 0.0166857 - mea: 0.1013927
# 	4001/50000: loss: 0.0166857 - mea: 0.1013900
# 	5001/50000: loss: 0.0166857 - mea: 0.1013927
# 	6001/50000: loss: 0.0166857 - mea: 0.1013927
# 	7001/50000: loss: 0.0166857 - mea: 0.1013900
# 	8001/50000: loss: 0.0166857 - mea: 0.1013927
# 	9001/50000: loss: 0.0166857 - mea: 0.1013927
# 	10001/50000: loss: 0.0166857 - mea: 0.1013900
# 	11001/50000: loss: 0.0166857 - mea: 0.1013927
# 	12001/50000: loss: 0.0166857 - mea: 0.1013927
# 	13001/50000: loss: 0.0166857 - mea: 0.1013900
# 	14001/50000: loss: 0.0166857 - mea: 0.1013927
# 	15001/50000: loss: 0.0166857 - mea: 0.1013927
# 	16001/50000: loss: 0.0166857 - mea: 0.1013900
# 	17001/50000: loss: 0.0166857 - mea: 0.1013927
# 	18001/50000: loss: 0.0166857 - mea: 0.1013927
# 	19001/50000: loss: 0.0166857 - mea: 0.1013900
# 	20001/50000: loss: 0.0166857 - mea: 0.1013927
# 	21001/50000: loss: 0.0166857 - mea: 0.1013927
# 	22001/50000: loss: 0.0166857 - mea: 0.1013900
# 	23001/50000: loss: 0.0166857 - mea: 0.1013927
# 	24001/50000: loss: 0.0166857 - mea: 0.1013927
# 	25001/50000: loss: 0.0166857 - mea: 0.1013900
# 	26001/50000: loss: 0.0166857 - mea: 0.1013927
# ...
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">squared_NALU</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/1m9j2ct0" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/1m9j2ct0</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">root_MLP</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/102hlggu" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/102hlggu</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194116-102hlggu</code><br/><br/>
# 	1/50000: loss: 284.5762329 - mea: 16.8499889
# 	1001/50000: loss: 0.0631955 - mea: 0.2083121
# 	2001/50000: loss: 0.0631937 - mea: 0.2082855
# 	3001/50000: loss: 0.0632031 - mea: 0.2083526
# 	4001/50000: loss: 0.0631937 - mea: 0.2082855
# 	5001/50000: loss: 0.0631937 - mea: 0.2082855
# 	6001/50000: loss: 0.0631937 - mea: 0.2082855
# 	7001/50000: loss: 0.0631937 - mea: 0.2082855
# 	8001/50000: loss: 0.0631937 - mea: 0.2082855
# 	9001/50000: loss: 0.0631937 - mea: 0.2082855
# 	10001/50000: loss: 0.0631937 - mea: 0.2082855
# 	11001/50000: loss: 0.0631937 - mea: 0.2082855
# 	12001/50000: loss: 0.0631937 - mea: 0.2082855
# 	13001/50000: loss: 0.0631937 - mea: 0.2082855
# 	14001/50000: loss: 0.0631937 - mea: 0.2082855
# 	15001/50000: loss: 0.0631937 - mea: 0.2082855
# 	16001/50000: loss: 0.0631937 - mea: 0.2082855
# 	17001/50000: loss: 0.0631937 - mea: 0.2082855
# 	18001/50000: loss: 0.0631937 - mea: 0.2082855
# 	19001/50000: loss: 0.0631937 - mea: 0.2082855
# 	20001/50000: loss: 0.0631937 - mea: 0.2082855
# 	21001/50000: loss: 0.0631937 - mea: 0.2082855
# 	22001/50000: loss: 0.0631937 - mea: 0.2082855
# 	23001/50000: loss: 0.0631937 - mea: 0.2082855
# 	24001/50000: loss: 0.0631937 - mea: 0.2082855
# 	25001/50000: loss: 0.0631937 - mea: 0.2082855
# 	26001/50000: loss: 0.0631937 - mea: 0.2082855
# 	27001/50000: loss: 0.0631937 - mea: 0.2082855
# 	28001/50000: loss: 0.0631937 - mea: 0.2082855
# 	29001/50000: loss: 0.0631937 - mea: 0.2082855
# 	30001/50000: loss: 0.0631937 - mea: 0.2082855
# 	31001/50000: loss: 0.0631937 - mea: 0.2082855
# 	32001/50000: loss: 0.0631937 - mea: 0.2082855
# 	33001/50000: loss: 0.0631937 - mea: 0.2082855
# 	34001/50000: loss: 0.0631937 - mea: 0.2082855
# 	35001/50000: loss: 0.0631937 - mea: 0.2082855
# 	36001/50000: loss: 0.0631937 - mea: 0.2082855
# 	37001/50000: loss: 0.0631937 - mea: 0.2082855
# 	38001/50000: loss: 0.0631937 - mea: 0.2082855
# 	39001/50000: loss: 0.0631937 - mea: 0.2082855
# 	40001/50000: loss: 0.0631937 - mea: 0.2082855
# 	41001/50000: loss: 0.0658168 - mea: 0.2109251
# 	42001/50000: loss: 0.0631937 - mea: 0.2082855
# 	43001/50000: loss: 0.0631937 - mea: 0.2082855
# 	44001/50000: loss: 0.0631937 - mea: 0.2082855
# 	45001/50000: loss: 0.0631937 - mea: 0.2082855
# 	46001/50000: loss: 0.0631937 - mea: 0.2082855
# 	47001/50000: loss: 0.0631937 - mea: 0.2082855
# 	48001/50000: loss: 0.0631937 - mea: 0.2082855
# 	49001/50000: loss: 0.0631937 - mea: 0.2082855
# model_type: MLP
# function: root
# test_result: 0.18106570839881897
# normalized_test_result: 3.4697628665629727
# <br/>Waiting for W&B process to finish, PID 1025<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194116-102hlggu/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194116-102hlggu/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.06319</td></tr><tr><td>mean_absolute_error</td><td>0.20829</td></tr><tr><td>_runtime</td><td>31</td></tr><tr><td>_timestamp</td><td>1623440507</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">root_MLP</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/102hlggu" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/102hlggu</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">root_NAC</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/2he6f6v0" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/2he6f6v0</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194155-2he6f6v0</code><br/><br/>
# 	1/50000: loss: 6.7213259 - mea: 2.5588174
# 	1001/50000: loss: 0.0450699 - mea: 0.1688710
# 	2001/50000: loss: 0.0417498 - mea: 0.1611167
# 	3001/50000: loss: 0.0419718 - mea: 0.1614885
# 	4001/50000: loss: 0.0410249 - mea: 0.1593877
# 	5001/50000: loss: 0.0392769 - mea: 0.1554545
# 	6001/50000: loss: 0.0383809 - mea: 0.1534177
# 	7001/50000: loss: 0.0376787 - mea: 0.1517839
# 	8001/50000: loss: 0.0370564 - mea: 0.1503112
# 	9001/50000: loss: 0.0364848 - mea: 0.1489597
# 	10001/50000: loss: 0.0359609 - mea: 0.1477043
# 	11001/50000: loss: 0.0354803 - mea: 0.1465679
# 	12001/50000: loss: 0.0350399 - mea: 0.1455474
# 	13001/50000: loss: 0.0346383 - mea: 0.1446489
# 	14001/50000: loss: 0.0342682 - mea: 0.1438292
# 	15001/50000: loss: 0.0339304 - mea: 0.1430951
# 	16001/50000: loss: 0.0336235 - mea: 0.1424363
# 	17001/50000: loss: 0.0333425 - mea: 0.1418156
# 	18001/50000: loss: 0.0330875 - mea: 0.1412512
# 	19001/50000: loss: 0.0328583 - mea: 0.1407427
# 	20001/50000: loss: 0.0326493 - mea: 0.1402836
# 	21001/50000: loss: 0.0324621 - mea: 0.1398762
# 	22001/50000: loss: 0.0322954 - mea: 0.1395243
# 	23001/50000: loss: 0.0321450 - mea: 0.1392068
# 	24001/50000: loss: 0.0320110 - mea: 0.1389358
# 	25001/50000: loss: 0.0318917 - mea: 0.1387070
# 	26001/50000: loss: 0.0317868 - mea: 0.1385109
# 	27001/50000: loss: 0.0316940 - mea: 0.1383366
# 	28001/50000: loss: 0.0316111 - mea: 0.1381891
# 	29001/50000: loss: 0.0315402 - mea: 0.1380621
# 	30001/50000: loss: 0.0314776 - mea: 0.1379479
# 	31001/50000: loss: 0.0314233 - mea: 0.1378552
# 	32001/50000: loss: 0.0313737 - mea: 0.1377712
# 	33001/50000: loss: 0.0313331 - mea: 0.1377012
# 	34001/50000: loss: 0.0312978 - mea: 0.1376397
# 	35001/50000: loss: 0.0312658 - mea: 0.1375860
# 	36001/50000: loss: 0.0312385 - mea: 0.1375398
# 	37001/50000: loss: 0.0312147 - mea: 0.1374993
# 	38001/50000: loss: 0.0311946 - mea: 0.1374646
# 	39001/50000: loss: 0.0311770 - mea: 0.1374345
# 	40001/50000: loss: 0.0311610 - mea: 0.1374074
# 	41001/50000: loss: 0.0311478 - mea: 0.1373848
# 	42001/50000: loss: 0.0311357 - mea: 0.1373642
# 	43001/50000: loss: 0.0311254 - mea: 0.1373465
# 	44001/50000: loss: 0.0311165 - mea: 0.1373311
# 	45001/50000: loss: 0.0311079 - mea: 0.1373163
# 	46001/50000: loss: 0.0311017 - mea: 0.1373055
# 	47001/50000: loss: 0.0310949 - mea: 0.1372937
# 	48001/50000: loss: 0.0310897 - mea: 0.1372848
# 	49001/50000: loss: 0.0310840 - mea: 0.1372750
# model_type: NAC
# function: root
# test_result: 0.1202208399772644
# normalized_test_result: 1.8179532576856814
# <br/>Waiting for W&B process to finish, PID 1067<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194155-2he6f6v0/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194155-2he6f6v0/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.03108</td></tr><tr><td>mean_absolute_error</td><td>0.13727</td></tr><tr><td>_runtime</td><td>32</td></tr><tr><td>_timestamp</td><td>1623440547</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">root_NAC</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/2he6f6v0" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/2he6f6v0</a><br/>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">root_NALU</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/galmitr/INTERPOLATION" target="_blank">https://wandb.ai/galmitr/INTERPOLATION</a><br/>
#                 Run page: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/fcse8r64" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/fcse8r64</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194234-fcse8r64</code><br/><br/>
# 	1/50000: loss: 8.3164883 - mea: 2.8119428
# 	1001/50000: loss: 0.0154093 - mea: 0.1205957
# 	2001/50000: loss: 0.0128875 - mea: 0.1127877
# 	3001/50000: loss: 0.0110573 - mea: 0.1047929
# 	4001/50000: loss: 0.0094072 - mea: 0.0966364
# 	5001/50000: loss: 0.0078510 - mea: 0.0882059
# 	6001/50000: loss: 0.0063535 - mea: 0.0791773
# 	7001/50000: loss: 0.0048988 - mea: 0.0689847
# 	8001/50000: loss: 0.0038040 - mea: 0.0603444
# 	9001/50000: loss: 0.0033137 - mea: 0.0558943
# 	10001/50000: loss: 0.0031482 - mea: 0.0544466
# 	11001/50000: loss: 0.0029410 - mea: 0.0526236
# 	12001/50000: loss: 0.0027793 - mea: 0.0511843
# 	13001/50000: loss: 0.0026313 - mea: 0.0498328
# 	14001/50000: loss: 0.0024966 - mea: 0.0485720
# 	15001/50000: loss: 0.0023721 - mea: 0.0473766
# 	16001/50000: loss: 0.0022549 - mea: 0.0462199
# 	17001/50000: loss: 0.0021429 - mea: 0.0450836
# 	18001/50000: loss: 0.0020391 - mea: 0.0440032
# 	19001/50000: loss: 0.0019404 - mea: 0.0429485
# 	20001/50000: loss: 0.0018477 - mea: 0.0419324
# 	21001/50000: loss: 0.0017582 - mea: 0.0409257
# 	22001/50000: loss: 0.0016763 - mea: 0.0399812
# 	23001/50000: loss: 0.0015964 - mea: 0.0390355
# 	24001/50000: loss: 0.0015248 - mea: 0.0381695
# 	25001/50000: loss: 0.0014569 - mea: 0.0373296
# 	26001/50000: loss: 0.0013948 - mea: 0.0365432
# 	27001/50000: loss: 0.0013352 - mea: 0.0357724
# 	28001/50000: loss: 0.0012819 - mea: 0.0350694
# 	29001/50000: loss: 0.0012331 - mea: 0.0344148
# 	30001/50000: loss: 0.0011894 - mea: 0.0338186
# 	31001/50000: loss: 0.0011463 - mea: 0.0332180
# 	32001/50000: loss: 0.0011090 - mea: 0.0326916
# 	33001/50000: loss: 0.0010754 - mea: 0.0322111
# 	34001/50000: loss: 0.0010431 - mea: 0.0317404
# 	35001/50000: loss: 0.0010152 - mea: 0.0313310
# 	36001/50000: loss: 0.0009909 - mea: 0.0309709
# 	37001/50000: loss: 0.0009675 - mea: 0.0306201
# 	38001/50000: loss: 0.0009488 - mea: 0.0303404
# 	39001/50000: loss: 0.0009304 - mea: 0.0300594
# 	40001/50000: loss: 0.0009143 - mea: 0.0298141
# 	41001/50000: loss: 0.0009006 - mea: 0.0296044
# 	42001/50000: loss: 0.0008867 - mea: 0.0293901
# 	43001/50000: loss: 0.0008755 - mea: 0.0292170
# 	44001/50000: loss: 0.0008666 - mea: 0.0290823
# 	45001/50000: loss: 0.0008564 - mea: 0.0289228
# 	46001/50000: loss: 0.0008497 - mea: 0.0288209
# 	47001/50000: loss: 0.0008425 - mea: 0.0287104
# 	48001/50000: loss: 0.0008368 - mea: 0.0286234
# 	49001/50000: loss: 0.0008301 - mea: 0.0285175
# model_type: NALU
# function: root
# test_result: 0.027895670384168625
# normalized_test_result: 0.44907191770490523
# <br/>Waiting for W&B process to finish, PID 1107<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194234-fcse8r64/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/DL_project/EXPERIMENTS/wandb/run-20210611_194234-fcse8r64/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>49000</td></tr><tr><td>loss_(mse)</td><td>0.00083</td></tr><tr><td>mean_absolute_error</td><td>0.02852</td></tr><tr><td>_runtime</td><td>63</td></tr><tr><td>_timestamp</td><td>1623440617</td></tr><tr><td>_step</td><td>50</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_(mse)</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_absolute_error</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">root_NALU</strong>: <a href="https://wandb.ai/galmitr/INTERPOLATION/runs/fcse8r64" target="_blank">https://wandb.ai/galmitr/INTERPOLATION/runs/fcse8r64</a><br/>

# %% [markdown]
# ### Wandb pipeline

# %%
"""
pipeline for training model and tracking weights, gradients and metrics via Wandb
"""

def model_pipeline(hyperparameters):
    with wandb.init(project=f"{hyperparameters['project']}",
                    group=f"{hyperparameters['function']}", 
                    job_type=f"{hyperparameters['model']}",
                    name=f"{hyperparameters['function']}_{hyperparameters['model']}",
                    tags=f"{hyperparameters['tags']}",
                    config=hyperparameters):
        config = wandb.config

        random_model, model, data, criterion, optimizer = make(config)
        # print(model)

        # data
        train_data, test_data = data
 
        # random_model
        random_mea = []
        for i in range(100):
            abs = test(random_model, test_data)
            random_mea.append(abs.mean().item())
        random_result = np.mean(random_mea)

        # model
        train(model, 
            train_data,
            criterion, 
            optimizer,
            config.NUM_ITERS)
        
        abs = test(model, test_data)
        result = abs.mean().item()
        normalized_result = 100.0 * result/random_result

        print('model_type:', config.model)
        print('function:', config.function)
        print('test_result:', result)
        print('normalized_test_result:', normalized_result)

        ###wand plots
        # id = FUNC_id[config.function]

        table_res = wandb.Table(data=[[config.function, result]], 
                                columns=["FUNCTION", "Mean_of_MAE"])
        
        table_norm_res = wandb.Table(data=[[config.function, normalized_result]], 
                                     columns=["FUNCTION", "Scaled_Mean_of_MAE"])

        wandb.log({
        'Results': wandb.plot.bar(table_res, 
                                "FUNCTION",
                                "Mean_of_MAE",
                                title="Results"),
                   
        'Normalized_Results': wandb.plot.bar(table_norm_res, 
                                            "FUNCTION",
                                            "Scaled_Mean_of_MAE", 
                                            title="Normalized_Results")
        })

    return model


def make(config):
    # Make the model
    model = MODELS[config.model](config.NUM_LAYERS, 
                                config.in_dim, 
                                config.HIDDEN_DIM, 
                                config.out_dim).model

    random_model = MLP(config.NUM_LAYERS, 
                        config.in_dim, 
                        config.HIDDEN_DIM, 
                        config.out_dim).model

    # Make the data
    data = generate_data(config.function,
                         config.num_train, 
                         config.num_test, 
                         config.dim, 
                         config.num_sum, 
                         config.RANGE)
    
    # Make the loss and optimizer
    criterion = F.mse_loss
    optimizer = torch.optim.RMSprop(model.parameters(), lr=config.LEARNING_RATE)

    # return random_model, model, criterion, optimizer
    return random_model, model, data, criterion, optimizer


def generate_data(function, num_train, num_test, dim, num_sum, support):

    fn = ARITHMETIC_FUNCTIONS[function]
    data = torch.FloatTensor(dim).uniform_(*support).unsqueeze_(1)
    X, y = [], []
    for i in range(num_train + num_test):
        idx_a = random.sample(range(dim), num_sum)
        idx_b = random.sample([x for x in range(dim) if x not in idx_a], num_sum)
        a, b = data[idx_a].sum(), data[idx_b].sum()
        X.append([a, b])
        y.append(fn(a, b))
    X = torch.FloatTensor(X)
    y = torch.FloatTensor(y).unsqueeze_(1)
    indices = list(range(num_train + num_test))
    np.random.shuffle(indices)
    X_train, y_train = X[indices[num_test:]], y[indices[num_test:]]
    X_test, y_test = X[indices[:num_test]], y[indices[:num_test]]

    return ((X_train, y_train), (X_test, y_test))


def train(model, train_data, criterion, optimizer, num_iters):
    wandb.watch(model, criterion, log="all", log_freq=1000)

    data, target = train_data
    # model.train()
    for i in range(num_iters):
        out = model(data)
        loss = criterion(out, target)
        mea = torch.mean(torch.abs(target - out))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if i % 1000 == 0:
            train_log(loss, mea, i, num_iters)

def train_log(loss, mea, epoch, num_iters):
    wandb.log({"epoch": epoch, "loss_(mse)": loss.item(), 'mean_absolute_error': mea.item()})
    print("\t{}/{}: loss: {:.7f} - mea: {:.7f}".format(epoch+1, num_iters, loss.item(), mea.item()))


def test(model, test_data):
    data, target = test_data
    with torch.no_grad():
        out = model(data)
        return torch.abs(target - out)
